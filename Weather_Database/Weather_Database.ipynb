# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get nearest city using citipy 
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Perform API call and add to dataframe 
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=30bf2fe27ff892997db32b4c7cc74ab3
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | bantry
# Processing Record 3 of Set 1 | saint george
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | upington
# Processing Record 9 of Set 1 | channel-port aux basques
# Processing Record 10 of Set 1 | okha
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | mazara del vallo
# Processing Record 13 of Set 1 | muros
# Processing Record 14 of Set 1 | lagoa
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | sola
# Processing Record 19 of Set 1 | indija
# Processing Record 20 of Set 1 | kavaratti
# Processing Record 21 of Set 1 | la baule-escoublac
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | nanortalik
# Processing Record 24 of Set 1 | lata
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | saint-augustin
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | lorengau
# Processing Record 30 of Set 1 | bardiyah
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | beisfjord
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 1 | beidao
# Processing Record 37 of Set 1 | san isidro
# Processing Record 38 of Set 1 | murray bridge
# Processing Record 39 of Set 1 | laguna
# Processing Record 40 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 1 | linxia
# Processing Record 42 of Set 1 | sinegorsk
# Processing Record 43 of Set 1 | maun
# Processing Record 44 of Set 1 | lasa
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | havelock
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | cabedelo
# Processing Record 1 of Set 2 | havre-saint-pierre
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | itacoatiara
# Processing Record 5 of Set 2 | airai
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 9 of Set 2 | kutum
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | maridi
# Processing Record 13 of Set 2 | dickson
# Processing Record 14 of Set 2 | lompoc
# Processing Record 15 of Set 2 | batsfjord
# Processing Record 16 of Set 2 | cayenne
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | quixada
# Processing Record 20 of Set 2 | tessalit
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | kochubey
# Processing Record 23 of Set 2 | balabac
# Processing Record 24 of Set 2 | seoul
# Processing Record 25 of Set 2 | palma
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | anadyr
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | mingguang
# Processing Record 33 of Set 2 | vanimo
# Processing Record 34 of Set 2 | kattivakkam
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | usinsk
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | praia da vitoria
# Processing Record 40 of Set 2 | mogok
# Processing Record 41 of Set 2 | haines junction
# Processing Record 42 of Set 2 | husavik
# Processing Record 43 of Set 2 | caravelas
# Processing Record 44 of Set 2 | severo-kurilsk
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 50 of Set 2 | diego de almagro
# Processing Record 1 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | zaraza
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | taltal
# Processing Record 7 of Set 3 | lavrentiya
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | abashiri
# Processing Record 10 of Set 3 | ati
# Processing Record 11 of Set 3 | nabire
# Processing Record 12 of Set 3 | prince rupert
# Processing Record 13 of Set 3 | mehamn
# Processing Record 14 of Set 3 | ahipara
# Processing Record 15 of Set 3 | derzhavinsk
# Processing Record 16 of Set 3 | brownfield
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | pandan
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | ilhabela
# Processing Record 21 of Set 3 | veraval
# Processing Record 22 of Set 3 | taunggyi
# Processing Record 23 of Set 3 | yeppoon
# Processing Record 24 of Set 3 | mahina
# Processing Record 25 of Set 3 | yuncheng
# Processing Record 26 of Set 3 | te anau
# Processing Record 27 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | wajima
# Processing Record 32 of Set 3 | broome
# Processing Record 33 of Set 3 | megion
# Processing Record 34 of Set 3 | kalianget
# Processing Record 35 of Set 3 | yellowknife
# Processing Record 36 of Set 3 | honningsvag
# Processing Record 37 of Set 3 | kampot
# Processing Record 38 of Set 3 | villanueva
# Processing Record 39 of Set 3 | bubaque
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | port-gentil
# Processing Record 43 of Set 3 | egvekinot
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | jiaozuo
# Processing Record 46 of Set 3 | hamilton
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | hambantota
# Processing Record 49 of Set 3 | avarua
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | marsa matruh
# Processing Record 4 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | mchinji
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | sinnamary
# Processing Record 9 of Set 4 | bom jesus
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | roma
# Processing Record 12 of Set 4 | itoman
# Processing Record 13 of Set 4 | suileng
# Processing Record 14 of Set 4 | manturovo
# Processing Record 15 of Set 4 | la ronge
# Processing Record 16 of Set 4 | killybegs
# Processing Record 17 of Set 4 | souillac
# Processing Record 18 of Set 4 | bekescsaba
# Processing Record 19 of Set 4 | loviisa
# Processing Record 20 of Set 4 | turmalina
# Processing Record 21 of Set 4 | chuy
# Processing Record 22 of Set 4 | mineros
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | itarema
# Processing Record 25 of Set 4 | bolshiye uki
# City not found. Skipping...
# Processing Record 26 of Set 4 | denpasar
# Processing Record 27 of Set 4 | burica
# City not found. Skipping...
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | fort william
# Processing Record 30 of Set 4 | fortuna
# Processing Record 31 of Set 4 | boende
# Processing Record 32 of Set 4 | acajutla
# Processing Record 33 of Set 4 | rio gallegos
# Processing Record 34 of Set 4 | urucara
# Processing Record 35 of Set 4 | vila
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | faya
# Processing Record 38 of Set 4 | ambanja
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | phangnga
# Processing Record 41 of Set 4 | carepa
# Processing Record 42 of Set 4 | marawi
# Processing Record 43 of Set 4 | tuatapere
# Processing Record 44 of Set 4 | tual
# Processing Record 45 of Set 4 | bandarbeyla
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | bogale
# Processing Record 48 of Set 4 | waipawa
# Processing Record 49 of Set 4 | matara
# Processing Record 50 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 5 | west wendover
# Processing Record 2 of Set 5 | asau
# Processing Record 3 of Set 5 | georgetown
# Processing Record 4 of Set 5 | port pirie
# Processing Record 5 of Set 5 | kozhevnikovo
# Processing Record 6 of Set 5 | komsomolskiy
# Processing Record 7 of Set 5 | turayf
# Processing Record 8 of Set 5 | tombouctou
# Processing Record 9 of Set 5 | saint paul
# Processing Record 10 of Set 5 | yulara
# Processing Record 11 of Set 5 | vryburg
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | salamanca
# Processing Record 14 of Set 5 | sao felix do xingu
# Processing Record 15 of Set 5 | bathsheba
# Processing Record 16 of Set 5 | kjollefjord
# Processing Record 17 of Set 5 | half moon bay
# Processing Record 18 of Set 5 | banjar
# Processing Record 19 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 5 | clyde river
# Processing Record 21 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 5 | hualmay
# Processing Record 23 of Set 5 | shingu
# Processing Record 24 of Set 5 | rypefjord
# Processing Record 25 of Set 5 | oranjemund
# Processing Record 26 of Set 5 | coromandel
# Processing Record 27 of Set 5 | moron
# Processing Record 28 of Set 5 | saldanha
# Processing Record 29 of Set 5 | butajira
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | aguimes
# Processing Record 32 of Set 5 | qaanaaq
# Processing Record 33 of Set 5 | mildura
# Processing Record 34 of Set 5 | quatre cocos
# Processing Record 35 of Set 5 | oakdale
# Processing Record 36 of Set 5 | yumen
# Processing Record 37 of Set 5 | kiama
# Processing Record 38 of Set 5 | kargil
# Processing Record 39 of Set 5 | barrow
# Processing Record 40 of Set 5 | vardo
# Processing Record 41 of Set 5 | chapais
# Processing Record 42 of Set 5 | grindavik
# Processing Record 43 of Set 5 | xining
# Processing Record 44 of Set 5 | itapirapua
# Processing Record 45 of Set 5 | faanui
# Processing Record 46 of Set 5 | looc
# Processing Record 47 of Set 5 | hobyo
# Processing Record 48 of Set 5 | monrovia
# Processing Record 49 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 5 | itaituba
# Processing Record 1 of Set 6 | comodoro rivadavia
# Processing Record 2 of Set 6 | banda aceh
# Processing Record 3 of Set 6 | gat
# Processing Record 4 of Set 6 | cascais
# Processing Record 5 of Set 6 | fort-shevchenko
# Processing Record 6 of Set 6 | mahebourg
# Processing Record 7 of Set 6 | zalantun
# Processing Record 8 of Set 6 | changji
# Processing Record 9 of Set 6 | champagnole
# Processing Record 10 of Set 6 | vao
# Processing Record 11 of Set 6 | condoto
# Processing Record 12 of Set 6 | burns lake
# Processing Record 13 of Set 6 | ambunti
# Processing Record 14 of Set 6 | litovko
# Processing Record 15 of Set 6 | port hardy
# Processing Record 16 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 6 | yar-sale
# Processing Record 18 of Set 6 | saint anthony
# Processing Record 19 of Set 6 | mandalgovi
# Processing Record 20 of Set 6 | pevek
# Processing Record 21 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 22 of Set 6 | lusambo
# Processing Record 23 of Set 6 | waitati
# Processing Record 24 of Set 6 | bantou
# Processing Record 25 of Set 6 | tahoua
# Processing Record 26 of Set 6 | bilibino
# Processing Record 27 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 6 | nouadhibou
# Processing Record 29 of Set 6 | dodge city
# Processing Record 30 of Set 6 | constitucion
# Processing Record 31 of Set 6 | cherskiy
# Processing Record 32 of Set 6 | cap malheureux
# Processing Record 33 of Set 6 | whitianga
# Processing Record 34 of Set 6 | thompson
# Processing Record 35 of Set 6 | tezu
# Processing Record 36 of Set 6 | wexford
# Processing Record 37 of Set 6 | doha
# Processing Record 38 of Set 6 | novyy urgal
# Processing Record 39 of Set 6 | zhigalovo
# Processing Record 40 of Set 6 | awbari
# Processing Record 41 of Set 6 | hasaki
# Processing Record 42 of Set 6 | jagatsinghapur
# Processing Record 43 of Set 6 | pedernales
# Processing Record 44 of Set 6 | rengo
# Processing Record 45 of Set 6 | empalme
# Processing Record 46 of Set 6 | dryden
# Processing Record 47 of Set 6 | port hedland
# Processing Record 48 of Set 6 | hovd
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | yar
# Processing Record 1 of Set 7 | acapulco
# Processing Record 2 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 7 | upernavik
# Processing Record 4 of Set 7 | pitimbu
# Processing Record 5 of Set 7 | mehran
# Processing Record 6 of Set 7 | kodinsk
# Processing Record 7 of Set 7 | sioux lookout
# Processing Record 8 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 7 | fare
# Processing Record 10 of Set 7 | oranjestad
# Processing Record 11 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 12 of Set 7 | bogovarovo
# Processing Record 13 of Set 7 | the valley
# Processing Record 14 of Set 7 | zhigansk
# Processing Record 15 of Set 7 | bar harbor
# Processing Record 16 of Set 7 | obluche
# City not found. Skipping...
# Processing Record 17 of Set 7 | sheltozero
# Processing Record 18 of Set 7 | barcelona
# Processing Record 19 of Set 7 | biltine
# Processing Record 20 of Set 7 | kirkkonummi
# Processing Record 21 of Set 7 | taoudenni
# Processing Record 22 of Set 7 | bambous virieux
# Processing Record 23 of Set 7 | athens
# Processing Record 24 of Set 7 | praia
# Processing Record 25 of Set 7 | ternate
# Processing Record 26 of Set 7 | san quintin
# Processing Record 27 of Set 7 | weligama
# Processing Record 28 of Set 7 | sambava
# Processing Record 29 of Set 7 | abha
# Processing Record 30 of Set 7 | kropotkin
# Processing Record 31 of Set 7 | jining
# Processing Record 32 of Set 7 | paciran
# Processing Record 33 of Set 7 | turiacu
# Processing Record 34 of Set 7 | flin flon
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | vestmannaeyjar
# Processing Record 37 of Set 7 | halden
# Processing Record 38 of Set 7 | phalodi
# Processing Record 39 of Set 7 | lalsot
# Processing Record 40 of Set 7 | ancud
# Processing Record 41 of Set 7 | romny
# Processing Record 42 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 7 | port augusta
# Processing Record 44 of Set 7 | parana
# Processing Record 45 of Set 7 | nyurba
# Processing Record 46 of Set 7 | chuguyevka
# Processing Record 47 of Set 7 | rio grande
# Processing Record 48 of Set 7 | scarborough
# Processing Record 49 of Set 7 | westport
# Processing Record 50 of Set 7 | nuuk
# Processing Record 1 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 8 | sonqor
# Processing Record 3 of Set 8 | namibe
# Processing Record 4 of Set 8 | iralaya
# Processing Record 5 of Set 8 | leh
# Processing Record 6 of Set 8 | key biscayne
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | camopi
# Processing Record 9 of Set 8 | zhangye
# Processing Record 10 of Set 8 | plastun
# Processing Record 11 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 8 | bonavista
# Processing Record 13 of Set 8 | mantua
# Processing Record 14 of Set 8 | lago da pedra
# Processing Record 15 of Set 8 | liberty
# Processing Record 16 of Set 8 | bethel
# Processing Record 17 of Set 8 | nome
# Processing Record 18 of Set 8 | bengkulu
# Processing Record 19 of Set 8 | san vicente de chucuri
# Processing Record 20 of Set 8 | mogadishu
# Processing Record 21 of Set 8 | tawang
# Processing Record 22 of Set 8 | vila velha
# Processing Record 23 of Set 8 | kalaleh
# Processing Record 24 of Set 8 | danjiangkou
# Processing Record 25 of Set 8 | olafsvik
# Processing Record 26 of Set 8 | salalah
# Processing Record 27 of Set 8 | piterka
# Processing Record 28 of Set 8 | hami
# Processing Record 29 of Set 8 | yerbogachen
# Processing Record 30 of Set 8 | virginia beach
# Processing Record 31 of Set 8 | tuy hoa
# Processing Record 32 of Set 8 | mutsu
# Processing Record 33 of Set 8 | manggar
# Processing Record 34 of Set 8 | sacramento
# Processing Record 35 of Set 8 | buala
# Processing Record 36 of Set 8 | sorong
# Processing Record 37 of Set 8 | askiz
# Processing Record 38 of Set 8 | coronel vivida
# Processing Record 39 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 8 | port lincoln
# Processing Record 41 of Set 8 | raigarh
# Processing Record 42 of Set 8 | locri
# Processing Record 43 of Set 8 | portland
# Processing Record 44 of Set 8 | diffa
# Processing Record 45 of Set 8 | beloha
# Processing Record 46 of Set 8 | cooma
# Processing Record 47 of Set 8 | sibu
# Processing Record 48 of Set 8 | wanning
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | dongsheng
# Processing Record 1 of Set 9 | fukue
# Processing Record 2 of Set 9 | saint-michel-des-saints
# Processing Record 3 of Set 9 | grand gaube
# Processing Record 4 of Set 9 | normal
# Processing Record 5 of Set 9 | tamiahua
# Processing Record 6 of Set 9 | sabzevar
# Processing Record 7 of Set 9 | puerto del rosario
# Processing Record 8 of Set 9 | calvinia
# Processing Record 9 of Set 9 | moorhead
# Processing Record 10 of Set 9 | vilhena
# Processing Record 11 of Set 9 | belmonte
# Processing Record 12 of Set 9 | mezen
# Processing Record 13 of Set 9 | katsuura
# Processing Record 14 of Set 9 | bilma
# Processing Record 15 of Set 9 | armidale
# Processing Record 16 of Set 9 | krasnoselkup
# Processing Record 17 of Set 9 | galesong
# Processing Record 18 of Set 9 | iracoubo
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | camacha
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 9 | saint-georges
# Processing Record 24 of Set 9 | margate
# Processing Record 25 of Set 9 | dullewala
# Processing Record 26 of Set 9 | voznesenye
# Processing Record 27 of Set 9 | anloga
# Processing Record 28 of Set 9 | kaitangata
# Processing Record 29 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 9 | batemans bay
# Processing Record 31 of Set 9 | ucluelet
# Processing Record 32 of Set 9 | waingapu
# Processing Record 33 of Set 9 | san lazaro
# Processing Record 34 of Set 9 | broken hill
# Processing Record 35 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 9 | hofn
# Processing Record 37 of Set 9 | alto araguaia
# Processing Record 38 of Set 9 | ndele
# Processing Record 39 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 9 | samarai
# Processing Record 41 of Set 9 | shenjiamen
# Processing Record 42 of Set 9 | kochevo
# Processing Record 43 of Set 9 | jumla
# Processing Record 44 of Set 9 | deer lake
# Processing Record 45 of Set 9 | mocuba
# Processing Record 46 of Set 9 | rab
# City not found. Skipping...
# Processing Record 47 of Set 9 | barra do garcas
# Processing Record 48 of Set 9 | mitsamiouli
# Processing Record 49 of Set 9 | ust-kuyga
# Processing Record 50 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 1 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 10 | fort nelson
# Processing Record 3 of Set 10 | dunedin
# Processing Record 4 of Set 10 | mitu
# Processing Record 5 of Set 10 | korla
# Processing Record 6 of Set 10 | muleba
# Processing Record 7 of Set 10 | oktyabrskoye
# Processing Record 8 of Set 10 | fonte boa
# Processing Record 9 of Set 10 | kavieng
# Processing Record 10 of Set 10 | vestmanna
# Processing Record 11 of Set 10 | naze
# Processing Record 12 of Set 10 | mendi
# Processing Record 13 of Set 10 | burnie
# Processing Record 14 of Set 10 | nalobikha
# Processing Record 15 of Set 10 | pietarsaari
# Processing Record 16 of Set 10 | sabang
# Processing Record 17 of Set 10 | bireun
# Processing Record 18 of Set 10 | kahului
# Processing Record 19 of Set 10 | ruteng
# Processing Record 20 of Set 10 | sapa
# Processing Record 21 of Set 10 | osorio
# Processing Record 22 of Set 10 | isiro
# Processing Record 23 of Set 10 | ahuimanu
# Processing Record 24 of Set 10 | alyangula
# Processing Record 25 of Set 10 | masvingo
# Processing Record 26 of Set 10 | tautira
# Processing Record 27 of Set 10 | karratha
# Processing Record 28 of Set 10 | quepos
# Processing Record 29 of Set 10 | goure
# Processing Record 30 of Set 10 | dingle
# Processing Record 31 of Set 10 | ferrol
# Processing Record 32 of Set 10 | makat
# Processing Record 33 of Set 10 | port elizabeth
# Processing Record 34 of Set 10 | verkhoyansk
# Processing Record 35 of Set 10 | maniitsoq
# Processing Record 36 of Set 10 | bulawayo
# Processing Record 37 of Set 10 | porto novo
# Processing Record 38 of Set 10 | bereda
# Processing Record 39 of Set 10 | paamiut
# Processing Record 40 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 10 | victor harbor
# Processing Record 43 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 44 of Set 10 | deputatskiy
# Processing Record 45 of Set 10 | seymchan
# Processing Record 46 of Set 10 | rundu
# Processing Record 47 of Set 10 | turbiv
# Processing Record 48 of Set 10 | paramonga
# Processing Record 49 of Set 10 | ponta do sol
# Processing Record 50 of Set 10 | ust-barguzin
# Processing Record 1 of Set 11 | sitka
# Processing Record 2 of Set 11 | rognan
# Processing Record 3 of Set 11 | maryborough
# Processing Record 4 of Set 11 | vila franca do campo
# Processing Record 5 of Set 11 | aswan
# Processing Record 6 of Set 11 | verkhnevilyuysk
# Processing Record 7 of Set 11 | leningradskiy
# Processing Record 8 of Set 11 | boshnyakovo
# Processing Record 9 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 10 of Set 11 | semnan
# Processing Record 11 of Set 11 | chiang rai
# Processing Record 12 of Set 11 | pinehurst
# Processing Record 13 of Set 11 | manta
# Processing Record 14 of Set 11 | port moresby
# Processing Record 15 of Set 11 | hede
# Processing Record 16 of Set 11 | rhyl
# Processing Record 17 of Set 11 | mahibadhoo
# Processing Record 18 of Set 11 | luanda
# Processing Record 19 of Set 11 | leshukonskoye
# Processing Record 20 of Set 11 | chifeng
# Processing Record 21 of Set 11 | stawell
# Processing Record 22 of Set 11 | tarut
# Processing Record 23 of Set 11 | awjilah
# Processing Record 24 of Set 11 | cockburn town
# Processing Record 25 of Set 11 | andenes
# Processing Record 26 of Set 11 | tura
# Processing Record 27 of Set 11 | sayyan
# Processing Record 28 of Set 11 | champua
# Processing Record 29 of Set 11 | bozoum
# Processing Record 30 of Set 11 | tarauaca
# Processing Record 31 of Set 11 | kirakira
# Processing Record 32 of Set 11 | homer
# Processing Record 33 of Set 11 | diamantina
# Processing Record 34 of Set 11 | acarau
# Processing Record 35 of Set 11 | magadan
# Processing Record 36 of Set 11 | port hawkesbury
# Processing Record 37 of Set 11 | ulaanbaatar
# Processing Record 38 of Set 11 | sao joao do paraiso
# Processing Record 39 of Set 11 | chernyshevskiy
# Processing Record 40 of Set 11 | yuxia
# Processing Record 41 of Set 11 | pokhara
# Processing Record 42 of Set 11 | tierralta
# Processing Record 43 of Set 11 | pacific grove
# Processing Record 44 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 11 | guerrero negro
# Processing Record 46 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 11 | safaga
# Processing Record 48 of Set 11 | harwich
# Processing Record 49 of Set 11 | merrill
# Processing Record 50 of Set 11 | birur
# Processing Record 1 of Set 12 | praya
# Processing Record 2 of Set 12 | iwanai
# Processing Record 3 of Set 12 | copiapo
# Processing Record 4 of Set 12 | rock springs
# Processing Record 5 of Set 12 | formosa
# Processing Record 6 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 7 of Set 12 | maldonado
# Processing Record 8 of Set 12 | sorland
# Processing Record 9 of Set 12 | kununurra
# Processing Record 10 of Set 12 | ilulissat
# Processing Record 11 of Set 12 | lethem
# Processing Record 12 of Set 12 | tete
# Processing Record 13 of Set 12 | aloleng
# Processing Record 14 of Set 12 | lahaina
# Processing Record 15 of Set 12 | sawakin
# Processing Record 16 of Set 12 | sattahip
# Processing Record 17 of Set 12 | fairbanks
# Processing Record 18 of Set 12 | mananjary
# Processing Record 19 of Set 12 | imbituba
# Processing Record 20 of Set 12 | rantauprapat
# Processing Record 21 of Set 12 | yurga
# Processing Record 22 of Set 12 | smolensk
# Processing Record 23 of Set 12 | aklavik
# Processing Record 24 of Set 12 | ilebo
# Processing Record 25 of Set 12 | kaduna
# Processing Record 26 of Set 12 | puerto carreno
# Processing Record 27 of Set 12 | komsomolets
# Processing Record 28 of Set 12 | poum
# Processing Record 29 of Set 12 | sagua la grande
# Processing Record 30 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 12 | zelenoborskiy
# Processing Record 32 of Set 12 | ballina
# Processing Record 33 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 12 | sept-iles
# Processing Record 35 of Set 12 | el astillero
# Processing Record 36 of Set 12 | krasnyy luch
# Processing Record 37 of Set 12 | ponta delgada
# Processing Record 38 of Set 12 | wagar
# Processing Record 39 of Set 12 | andra
# Processing Record 40 of Set 12 | tevaitoa
# Processing Record 41 of Set 12 | aksu
# Processing Record 42 of Set 12 | atikokan
# Processing Record 43 of Set 12 | honiara
# Processing Record 44 of Set 12 | norman wells
# Processing Record 45 of Set 12 | rawson
# Processing Record 46 of Set 12 | mayumba
# Processing Record 47 of Set 12 | mount gambier
# Processing Record 48 of Set 12 | yamnytsya
# Processing Record 49 of Set 12 | baykit
# Processing Record 50 of Set 12 | moyale
# Processing Record 1 of Set 13 | rio pardo de minas
# Processing Record 2 of Set 13 | stettler
# Processing Record 3 of Set 13 | shimoda
# Processing Record 4 of Set 13 | soe
# Processing Record 5 of Set 13 | sterling
# Processing Record 6 of Set 13 | kichera
# Processing Record 7 of Set 13 | san joaquin
# Processing Record 8 of Set 13 | vammala
# Processing Record 9 of Set 13 | hwange
# Processing Record 10 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 13 | mudanya
# Processing Record 12 of Set 13 | delta del tigre
# Processing Record 13 of Set 13 | namie
# Processing Record 14 of Set 13 | makakilo city
# Processing Record 15 of Set 13 | saint-doulchard
# Processing Record 16 of Set 13 | inhambane
# Processing Record 17 of Set 13 | viedma
# Processing Record 18 of Set 13 | jalu
# Processing Record 19 of Set 13 | hannibal
# Processing Record 20 of Set 13 | kaseda
# Processing Record 21 of Set 13 | shouguang
# Processing Record 22 of Set 13 | sulangan
# Processing Record 23 of Set 13 | lakes entrance
# Processing Record 24 of Set 13 | miracatu
# Processing Record 25 of Set 13 | klaksvik
# Processing Record 26 of Set 13 | gombong
# Processing Record 27 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 13 | mayo
# Processing Record 29 of Set 13 | yate
# Processing Record 30 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 13 | thinadhoo
# Processing Record 32 of Set 13 | shibarghan
# City not found. Skipping...
# Processing Record 33 of Set 13 | nahariyya
# Processing Record 34 of Set 13 | krasnorechenskiy
# Processing Record 35 of Set 13 | russell
# Processing Record 36 of Set 13 | palmer
# Processing Record 37 of Set 13 | the pas
# Processing Record 38 of Set 13 | santa cruz del sur
# Processing Record 39 of Set 13 | zhuhai
# Processing Record 40 of Set 13 | stokmarknes
# Processing Record 41 of Set 13 | porto murtinho
# Processing Record 42 of Set 13 | port blair
# Processing Record 43 of Set 13 | chiman
# Processing Record 44 of Set 13 | yuzhno-kurilsk
# Processing Record 45 of Set 13 | ocampo
# Processing Record 46 of Set 13 | beruwala
# Processing Record 47 of Set 13 | srivardhan
# Processing Record 48 of Set 13 | grand-lahou
# Processing Record 49 of Set 13 | cohoes
# Processing Record 50 of Set 13 | obidos
# Processing Record 1 of Set 14 | ulaangom
# Processing Record 2 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 3 of Set 14 | mackay
# Processing Record 4 of Set 14 | oussouye
# Processing Record 5 of Set 14 | prestea
# Processing Record 6 of Set 14 | kankon
# Processing Record 7 of Set 14 | san buenaventura
# Processing Record 8 of Set 14 | calama
# Processing Record 9 of Set 14 | aksha
# Processing Record 10 of Set 14 | santo estevao
# Processing Record 11 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 12 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 14 | turukhansk
# Processing Record 14 of Set 14 | benalla
# Processing Record 15 of Set 14 | huarmey
# Processing Record 16 of Set 14 | gobo
# Processing Record 17 of Set 14 | fort madison
# Processing Record 18 of Set 14 | wasilla
# Processing Record 19 of Set 14 | yakima
# Processing Record 20 of Set 14 | spring hill
# Processing Record 21 of Set 14 | provideniya
# Processing Record 22 of Set 14 | araguacu
# Processing Record 23 of Set 14 | kurchum
# Processing Record 24 of Set 14 | cairns
# Processing Record 25 of Set 14 | santa clara
# Processing Record 26 of Set 14 | bukama
# Processing Record 27 of Set 14 | mazagao
# Processing Record 28 of Set 14 | goderich
# Processing Record 29 of Set 14 | windhoek
# Processing Record 30 of Set 14 | olinda
# Processing Record 31 of Set 14 | tigil
# Processing Record 32 of Set 14 | nerchinskiy zavod
# Processing Record 33 of Set 14 | okhotsk
# Processing Record 34 of Set 14 | mazyr
# Processing Record 35 of Set 14 | vanersborg
# Processing Record 36 of Set 14 | shache
# Processing Record 37 of Set 14 | sangar
# Processing Record 38 of Set 14 | ostrovnoy
# Processing Record 39 of Set 14 | bowling green
# Processing Record 40 of Set 14 | caarapo
# Processing Record 41 of Set 14 | amahai
# Processing Record 42 of Set 14 | high level
# Processing Record 43 of Set 14 | abu samrah
# Processing Record 44 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 14 | san jeronimo
# Processing Record 46 of Set 14 | filingue
# Processing Record 47 of Set 14 | evensk
# Processing Record 48 of Set 14 | riyadh
# Processing Record 49 of Set 14 | segou
# Processing Record 50 of Set 14 | puerto madryn
# Processing Record 1 of Set 15 | kloulklubed
# Processing Record 2 of Set 15 | kamakwie
# Processing Record 3 of Set 15 | dalvik
# Processing Record 4 of Set 15 | saint-joseph
# Processing Record 5 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 15 | dongfeng
# Processing Record 7 of Set 15 | yangjiang
# Processing Record 8 of Set 15 | urusha
# Processing Record 9 of Set 15 | catamarca
# Processing Record 10 of Set 15 | shibetsu
# Processing Record 11 of Set 15 | springbok
# Processing Record 12 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 15 | kudahuvadhoo
# Processing Record 14 of Set 15 | pangody
# Processing Record 15 of Set 15 | arman
# Processing Record 16 of Set 15 | stephenville
# Processing Record 17 of Set 15 | leesburg
# Processing Record 18 of Set 15 | ossora
# Processing Record 19 of Set 15 | sumter
# Processing Record 20 of Set 15 | nizhniy kuranakh
# Processing Record 21 of Set 15 | amvrosiyivka
# Processing Record 22 of Set 15 | ivanteyevka
# Processing Record 23 of Set 15 | adrar
# Processing Record 24 of Set 15 | atbasar
# Processing Record 25 of Set 15 | jardim
# Processing Record 26 of Set 15 | labuan
# Processing Record 27 of Set 15 | tecoanapa
# Processing Record 28 of Set 15 | atherton
# Processing Record 29 of Set 15 | puerto el triunfo
# Processing Record 30 of Set 15 | zhumadian
# Processing Record 31 of Set 15 | poplar bluff
# Processing Record 32 of Set 15 | northam
# Processing Record 33 of Set 15 | maumere
# Processing Record 34 of Set 15 | danilovka
# Processing Record 35 of Set 15 | adolfo lopez mateos
# Processing Record 36 of Set 15 | vila do maio
# Processing Record 37 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 15 | beringovskiy
# Processing Record 39 of Set 15 | darhan
# Processing Record 40 of Set 15 | phanat nikhom
# Processing Record 41 of Set 15 | coquimbo
# Processing Record 42 of Set 15 | dukat
# Processing Record 43 of Set 15 | astoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Carnarvon      AU -24.8667  113.6333     86.07        51
# 1                    Bantry      IE  51.6833   -9.4500     42.28        88
# 2              Saint George      US  37.1041 -113.5841     52.36        36
# 3                    Atuona      PF  -9.8000 -139.0333     78.93        77
# 4                      Hilo      US  19.7297 -155.0900     77.79        88
# 5                    Castro      BR -24.7911  -50.0119     66.58        90
# 6                   Isangel      VU -19.5500  169.2667     86.11        79
# 7                  Upington      ZA -28.4478   21.2561     71.98        88
# 8  Channel-Port Aux Basques      CA  47.5702  -59.1367     27.43        69
# 9                      Okha      RU  53.5739  142.9478     -1.73        87
#
#    Cloudiness  Wind Speed Current Description
# 0           0        9.22           clear sky
# 1          34        3.36    scattered clouds
# 2           5        1.48           clear sky
# 3          47       24.05    scattered clouds
# 4          85        5.99     overcast clouds
# 5          93        3.62     overcast clouds
# 6         100        4.61          light rain
# 7           0        5.75           clear sky
# 8         100       18.03     overcast clouds
# 9          94       15.19     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
